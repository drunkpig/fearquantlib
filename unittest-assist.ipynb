# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from fearquantlib.wavelib import *

# %%
code = "SH.600703"
df = get_df_of_code(code, "2019-09-20", "2019-10-21", KLType.K_30M)
# Out:
# 2019-10-26 19:17:06,061 [open_context_base.py] _socket_reconnect_and_wait_ready:256: Start connecting: host=localhost; port=11111;
# 2019-10-26 19:17:06,100 [open_context_base.py] on_connected:344: Connected : conn_id=1;
# 2019-10-26 19:17:06,134 [open_context_base.py] _handle_init_connect:444: InitConnect ok: conn_id=1; info={'server_version': 203, 'login_user_id': 1509176, 'conn_id': 6593817613501781148, 'conn_key': '079B5D162FF2815B', 'keep_alive_interval': 10, 'is_encrypt': False};

# %%
df15 = do_compute_df_bar(df)
#df15[df15._macd_bar_tag==-2]
df15

# last_idx = df[df[rg_field_name] != area].tail(1).index[0]
# dftemp = df[df.index > last_idx].copy().reset_index(drop=True)
# Out:
#           code             time_key  close   high    low  macd_bar     ma5  \
# 0    SH.600703  2019-09-20 10:00:00  15.21  15.68  14.98       NaN     NaN
# 1    SH.600703  2019-09-20 10:30:00  15.48  15.51  15.14       NaN     NaN
# 2    SH.600703  2019-09-20 11:00:00  15.28  15.67  15.20       NaN     NaN
# 3    SH.600703  2019-09-20 11:30:00  15.28  15.32  15.06       NaN     NaN
# 4    SH.600703  2019-09-20 13:30:00  15.35  15.45  15.15       NaN  15.320
# 5    SH.600703  2019-09-20 14:00:00  15.28  15.48  15.25       NaN  15.334
# 6    SH.600703  2019-09-20 14:30:00  15.29  15.39  15.23       NaN  15.296
# 7    SH.600703  2019-09-20 15:00:00  15.34  15.34  15.16       NaN  15.308
# 8    SH.600703  2019-09-23 10:00:00  15.36  15.61  15.10       NaN  15.324
# 9    SH.600703  2019-09-23 10:30:00  15.72  16.05  15.35       NaN  15.398
# 10   SH.600703  2019-09-23 11:00:00  15.93  16.18  15.67       NaN  15.528
# 11   SH.600703  2019-09-23 11:30:00  15.76  16.01  15.70       NaN  15.622
# 12   SH.600703  2019-09-23 13:30:00  15.57  15.81  15.32       NaN  15.668
# 13   SH.600703  2019-09-23 14:00:00  15.35  15.58  15.32       NaN  15.666
# 14   SH.600703  2019-09-23 14:30:00  15.53  15.56  15.22       NaN  15.628
# 15   SH.600703  2019-09-23 15:00:00  15.58  15.72  15.45       NaN  15.558
# 16   SH.600703  2019-09-24 10:00:00  16.18  16.36  15.47       NaN  15.642
# 17   SH.600703  2019-09-24 10:30:00  16.08  16.35  15.97       NaN  15.744
# 18   SH.600703  2019-09-24 11:00:00  16.06  16.28  15.99       NaN  15.886
# 19   SH.600703  2019-09-24 11:30:00  15.85  16.18  15.77       NaN  15.950
# 20   SH.600703  2019-09-24 13:30:00  15.89  15.97  15.82       NaN  16.012
# 21   SH.600703  2019-09-24 14:00:00  15.93  16.15  15.87       NaN  15.962
# 22   SH.600703  2019-09-24 14:30:00  16.07  16.26  15.89       NaN  15.960
# 23   SH.600703  2019-09-24 15:00:00  16.15  16.26  16.03       NaN  15.978
# 24   SH.600703  2019-09-25 10:00:00  15.26  16.00  15.26       NaN  15.860
# 25   SH.600703  2019-09-25 10:30:00  15.33  15.53  15.17       NaN  15.748
# 26   SH.600703  2019-09-25 11:00:00  15.47  15.55  15.32       NaN  15.656
# 27   SH.600703  2019-09-25 11:30:00  15.29  15.51  15.20       NaN  15.500
# 28   SH.600703  2019-09-25 13:30:00  15.27  15.28  15.15       NaN  15.324
# 29   SH.600703  2019-09-25 14:00:00  15.26  15.42  15.21       NaN  15.324
# 19   15.789    0.16              0                g            0
# 20   15.785    0.23              0                g            2
# 21   15.802    0.16              0                g            0
# 22   15.852    0.11              0                g            0
# 23   15.932    0.05              0                g            1
# 24   15.905   -0.05              0                g           -1
# 25   15.880   -0.13              0                g            0
# 26   15.809   -0.15              0                g            0
# 27   15.730   -0.23              0                g            0
# 28   15.651   -0.33              0                g           -2
# 29   15.592   -0.27              0                g            0
# ..      ...     ...            ...              ...          ...
# 106  13.623   -0.09              0                g            0
# 107  13.589   -0.05              0                g            0
# 108  13.569   -0.03              0                g            0
# 109  13.533   -0.02             -1                g           -1
# 110  13.512   -0.03              0                g            0
# 111  13.480   -0.06             -2                g            0
# 112  13.471   -0.07              0                g            0
# 113  13.451   -0.09             -1                g           -2
# 114  13.422   -0.09              0                g            0
# 115  13.391   -0.09              0                g            0
# 116  13.353   -0.07             -2                g            0
# 117  13.324   -0.07              0                g            0
# 118  13.287   -0.08              0                g            0
# 119  13.268   -0.06             -1                g            0
# 120  13.255   -0.05              0                g            0
# 121  13.254   -0.03              0                g            0
# 122  13.225   -0.03              0                g            0
# 123  13.187   -0.02             -1                g           -1
# 124  13.138   -0.07              0                g            0
# 125  13.099   -0.11              0                g            0
# 126  13.061   -0.17             -2                g            0
# 127  13.018   -0.18              0                g           -2
# 128  12.996   -0.17              0                g            0
# 129  12.952   -0.12              0                g            0
# 130  12.899   -0.09              0                g            0
# 131  12.855   -0.04             -1                g            0
# 132  12.823   -0.01              0                g           -1
# 133  12.805   -0.02              0                g            0
# 134  12.808   -0.03              0                g            0
# 135  12.814    0.00              0                g            0
#
#     _em_bar_rg_tag
# 0                g
# 1                g
# 2                g
# 3                g
# 4                g
# 5                g
# 6                g
# 7                g
# 8                g
# 9                r
# 10               r
# 11               r
# 12               r
# 13               r
# 14               r
# 15               r
# 16               r
# 17               r
# 18               r
# 19               r
# 20               r
# 21               r
# 22               r
# 23               r
# 24               r
# 25               g
# 26               g
# 27               g
# 28               g
# 29               g
# ..             ...
# 106              g
# 107              g
# 108              g
# 109              g
# 110              g
# 111              g
# 112              g
# 113              g
# 114              g
# 115              g
# 116              g
# 117              g
# 118              g
# 119              g
# 120              g
# 121              g
# 122              g
# 123              g
# 124              g
# 125              g
# 126              g
# 127              g
# 128              g
# 129              g
# 130              g
# 131              g
# 132              g
# 133              g
# 134              g
# 135              g
#
# [136 rows x 13 columns]

# %%
df15.loc[133:135,'_macd_bar_rg_tag']='r'

df15[df15.index]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-05db63cdf1a8> in <module>
#       1 df15.loc[133:135,'_macd_bar_rg_tag']='r'
#       2
# ----> 3 df15[df15.index in [1,111]]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
colors = tuple(np.where(df15["macd_bar"]>0, 'r', 'g'))

df15['macd_bar'].plot(kind='bar', color= colors, figsize=(20,7) )

# %%
ct = bottom_divergence_cnt(df15, "macd_bar", "close")
ct
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-337f8bca6eea> in <module>
# ----> 1 ct = bottom_divergence_cnt(df15, "macd_bar", "close")
#       2 ct
#
# D:\workspace\fearquantlib\fearquantlib\wavelib.py in bottom_divergence_cnt(df, bar_field, value_field)
#     344     val_successive_areas = __find_successive_areas(val_array)  # TODO bug, 返回了2个值
#     345     # 然后找出来最大长度的区
# --> 346     len1 = max(map(lambda p: p[1] - p[0] + 1, bar_successive_areas))  # TODO 这里有个bug，价格和bar都要下降，这里暂时没有做检查
#     347     len2 = max(map(lambda p: p[1] - p[0] + 1, val_successive_areas))
#     348     return max(len1, len2)
#
# ValueError: max() arg is an empty sequence

# %%
bar_green_wave_cnt(df15)
